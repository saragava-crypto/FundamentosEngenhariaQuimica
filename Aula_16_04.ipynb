# %% [markdown]
# <a href="https://colab.research.google.com/github/saragava-crypto/FundamentosEngenhariaQuimica/blob/main/Aula_16_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def soma(a,b):
  return a+b

def subtrai (a,b):
  return a-b
